# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/DataScienceApplicationsInComputerVision/blob/main/Class07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Object Recognition and Tracking with OpenCV**
# OpenCV is a versatile open-source library fundamental to computer vision, primarily utilized for object recognition and tracking across sectors like security and industrial automation. While recognition identifies elements using methods ranging from traditional SIFT and ORB interest points to modern convolutional neural networks (CNNs), tracking involves following an object's position over time using algorithms like KCF for speed or CSRT for accuracy. Specific applications, such as facial recognition, often leverage Haar Cascades for detection or deep learning models for precision. Successful implementation requires defining a precise Region of Interest (ROI) to focus processing, alongside performance optimization through frame resizing or GPU acceleration to balance metrics like frames per second (FPS) with detection reliability.

# %%
# Importing all the necessary libraries and resources:
import cv2
import numpy as np
from google.colab import files
from google.colab.patches import cv2_imshow

# %% [markdown]
# ## **Example: Object Recognition in Video with OpenCV**
# Object recognition and tracking with OpenCV are extremely powerful tools, applicable in a wide range of areas, from security to robotics and entertainment. With careful implementation and a focus on performance optimization, it is possible to create systems that not only accurately identify and track objects but also operate efficiently in challenging environments. OpenCV provides the flexibility and tools necessary to develop advanced solutions, enabling computer vision professionals to fully exploit the potential of this technology. In the following example, we use the algorithm to identify shapes in an YouTube video.

# %%
# Uploading the video:
uploaded = files.upload()
video_path = next(iter(uploaded))
cap = cv2.VideoCapture(video_path)
# Out:
#      <input type="file" id="files-32b1d31a-64ea-46cf-95fc-09e8eb0270f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-32b1d31a-64ea-46cf-95fc-09e8eb0270f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Initializing the Tracker (Using CSRT for high accuracy)
tracker = cv2.TrackerCSRT_create()

# %%
# Reading the first frame:
ret, frame = cap.read()
if not ret:
    print("Failed to read video")
else:
    # cv2.selectROI does NOT work in Colab, hence the ROI must be defined manually:
    roi = (100, 100, 200, 200)

    # Initializing tracker with the first frame and ROI:
    tracker.init(frame, roi)

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Updating the tracking:
        success, box = tracker.update(frame)

        # Drawing ROI on the image:
        if success:
            (x, y, w, h) = [int(v) for v in box]
            cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 2)
            cv2.putText(frame, "Tracking", (x, y - 5),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
        else:
            cv2.putText(frame, "Lost", (100, 80),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        # Displaying the frame:
        cv2_imshow(frame)

    cap.release()
