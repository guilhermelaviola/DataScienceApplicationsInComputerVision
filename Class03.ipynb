# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermelaviola/DataScienceApplicationsInComputerVision/blob/main/Class03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Deep Neural Networks (DNNs)**
# Deep Neural Networks (DNNs) represent a transformative leap in artificial intelligence, utilizing multiple hidden layers of interconnected neurons to extract complex, hierarchical patterns from massive datasets. By employing advanced architectures like ResNet or DenseNet to overcome training obstacles like gradient fading, these models achieve unprecedented precision in tasks such as computer vision and natural language processing. The training process involves optimizing parameters via algorithms like Adam and applying regularization techniques—such as Dropout and Batch Normalization—to ensure the model generalizes well to new data rather than just memorizing training examples. Supported by powerful Python libraries like TensorFlow and Keras, DNNs have moved from theoretical research to practical, high-impact applications, including autonomous driving, medical diagnostics, and superior image recognition.

# %%
# Importing all the necessary libraries:
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ## **Example: Multilayer Perceptron (MLP)**
# Following we can see a solid, standard implementation for a Multilayer Perceptron (MLP) approach to image classification. Here we can see how to use processing steps like normalization and one-hot encoding, and your use of Dropout is a smart move to keep that dense network from just memorizing the training set.

# %%
# Loading the CIFAR-10 dataset:
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# ...
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Normalizing input data to the range [0, 1]:
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# Applying One-Hot Encoding to class labels:
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# %%
# Defining the DNN structure:
model = models.Sequential([
    layers.Flatten(input_shape=(32, 32, 3)),
    layers.Dense(512, activation='relu'),
    layers.Dropout(0.5), # Dropout to avoid overfitting.
    layers.Dense(256, activation='relu'),
    layers.Dropout(0.5),
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax') # Output layer with softmax for classification.
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compiling the model:
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# Training the model:
history = model.fit(X_train, y_train, epochs=20, validation_split=0.2, batch_size=64)

# Evaluating the model on test data:
test_loss, test_acc = model.evaluate(X_test, y_test)
print(f'Accuracy on test: {test_acc}')
# Out:
# Epoch 1/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 26s 38ms/step - accuracy: 0.1491 - loss: 2.2788 - val_accuracy: 0.2324 - val_loss: 2.0183
# Epoch 2/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 22s 35ms/step - accuracy: 0.2099 - loss: 2.0688 - val_accuracy: 0.2551 - val_loss: 1.9852
# Epoch 3/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 42s 37ms/step - accuracy: 0.2135 - loss: 2.0407 - val_accuracy: 0.2665 - val_loss: 1.9872
# Epoch 4/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.2267 - loss: 2.0173 - val_accuracy: 0.2696 - val_loss: 1.9954
# Epoch 5/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 41s 37ms/step - accuracy: 0.2288 - loss: 2.0076 - val_accuracy: 0.2734 - val_loss: 1.9615
# Epoch 6/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 40s 36ms/step - accuracy: 0.2340 - loss: 2.0036 - val_accuracy: 0.2892 - val_loss: 1.9649
# Epoch 7/20
# 625/625 ━━━━━━━━━━━━━━━━━━━━ 23s 37ms/step - accuracy: 0.2372 - loss: 1.9943 - val_accuracy: 0.2664 - val_loss: 1.9656
# Epoch 8/20
# ...
